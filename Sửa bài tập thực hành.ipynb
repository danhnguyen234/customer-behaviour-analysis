# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls
# Out:
# drive  sample_data

# %%
import pandas as pd

# %%
# copy path
df_1 = pd.read_csv('/content/drive/MyDrive/MindX/MindX 18+ | D4E50/Day 12: Preprocessing và EDA dữ liệu/Data Practices/mexico-real-estate-1.csv')

# %%
df_1
# Out:
#     property_type                            state        lat         lon  \
# 0           house                 Estado de México  19.560181  -99.233528
# 1           house                       Nuevo León  25.688436 -100.198807
# 2       apartment                         Guerrero  16.767704  -99.764383
# 3       apartment                         Guerrero  16.829782  -99.911012
# 4           house  Veracruz de Ignacio de la Llave        NaN         NaN
# ..            ...                              ...        ...         ...
# 695         house                          Morelos        NaN         NaN
# 696         house                          Yucatán  21.050653  -89.558841
# 697         house                          Yucatán  21.343796  -89.262060
# 698     apartment                       Nuevo León        NaN         NaN
# 699         house                        Querétaro  20.587378 -100.418361
#
#      area_m2    price_usd
# 0      150.0   $67,965.56
# ...

# %%
df_2 = pd.read_csv('/content/drive/MyDrive/MindX/MindX 18+ | D4E50/Day 12: Preprocessing và EDA dữ liệu/Data Practices/mexico-real-estate-2.csv')
df_2.head()
# Out:
#   property_type       state        lat         lon  area_m2  price_mxn
# 0     apartment  Nuevo León  25.721081 -100.345581     72.0  1300000.0
# 1     apartment      Puebla        NaN         NaN    190.0  2500000.0
# 2         house     Morelos  23.634501 -102.552788    360.0  5300000.0
# 3         house     Morelos        NaN         NaN     76.0   820000.0
# 4         house      Puebla        NaN         NaN    200.0  1100000.0

# %%
df_3 = pd.read_csv('/content/drive/MyDrive/MindX/MindX 18+ | D4E50/Day 12: Preprocessing và EDA dữ liệu/Data Practices/mexico-real-estate-3.csv')
df_3.head()
# Out:
#   property_type                            place_with_parent_names  \
# 0     apartment  |México|Distrito Federal|Gustavo A. Madero|Acu...
# 1         house           |México|Estado de México|Toluca|Metepec|
# 2         house  |México|Estado de México|Toluca|Toluca de Lerd...
# 3         house        |México|Morelos|Temixco|Burgos Bugambilias|
# 4     apartment  |México|Veracruz de Ignacio de la Llave|Veracruz|
#
#                   lat-lon  area_m2  price_usd
# 0     19.52589,-99.151703     71.0   48550.59
# 1  19.2640539,-99.5727534    233.0  168636.73
# 2    19.268629,-99.671722    300.0   86932.69
# 3                     NaN    275.0  263432.41
# 4    19.511938,-96.871956     84.0   68508.67

# %% [markdown]
# #Data Preprocessing

# %% [markdown]
# ##Table 1

# %%
df_1.head()
# Out:
#   property_type                            state        lat         lon  \
# 0         house                 Estado de México  19.560181  -99.233528
# 1         house                       Nuevo León  25.688436 -100.198807
# 2     apartment                         Guerrero  16.767704  -99.764383
# 3     apartment                         Guerrero  16.829782  -99.911012
# 4         house  Veracruz de Ignacio de la Llave        NaN         NaN
#
#    area_m2   price_usd
# 0    150.0  $67,965.56
# 1    186.0  $63,223.78
# 2     82.0  $84,298.37
# 3    150.0  $94,308.80
# 4    175.0  $94,835.67

# %%
df_1.dtypes
# Out:
# property_type     object
# state             object
# lat              float64
# lon              float64
# area_m2          float64
# price_usd         object
# dtype: object

# %%
df_1['price_usd'] = df_1['price_usd'].str.replace('$', '').str.replace(',', '').astype(float)
# Out:
# <ipython-input-15-e0cc854bc7b1>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_1['price_usd'] = df_1['price_usd'].str.replace('$', '').str.replace(',', '').astype(float)

# %%
df_1.dtypes
# Out:
# property_type     object
# state             object
# lat              float64
# lon              float64
# area_m2          float64
# price_usd        float64
# dtype: object

# %%
df_1.head()
# Out:
#   property_type                            state        lat         lon  \
# 0         house                 Estado de México  19.560181  -99.233528
# 1         house                       Nuevo León  25.688436 -100.198807
# 2     apartment                         Guerrero  16.767704  -99.764383
# 3     apartment                         Guerrero  16.829782  -99.911012
# 4         house  Veracruz de Ignacio de la Llave        NaN         NaN
#
#    area_m2  price_usd
# 0    150.0   67965.56
# 1    186.0   63223.78
# 2     82.0   84298.37
# 3    150.0   94308.80
# 4    175.0   94835.67

# %% [markdown]
# ##Table 2

# %%
df_2.head()
# Out:
#   property_type       state        lat         lon  area_m2  price_mxn
# 0     apartment  Nuevo León  25.721081 -100.345581     72.0  1300000.0
# 1     apartment      Puebla        NaN         NaN    190.0  2500000.0
# 2         house     Morelos  23.634501 -102.552788    360.0  5300000.0
# 3         house     Morelos        NaN         NaN     76.0   820000.0
# 4         house      Puebla        NaN         NaN    200.0  1100000.0

# %%
df_2.dtypes
# Out:
# property_type     object
# state             object
# lat              float64
# lon              float64
# area_m2          float64
# price_mxn        float64
# dtype: object

# %%
df_2['price_usd'] = df_2['price_mxn'] * 0.056

# %%
df_2
# Out:
#     property_type             state        lat         lon  area_m2  \
# 0       apartment        Nuevo León  25.721081 -100.345581     72.0
# 1       apartment            Puebla        NaN         NaN    190.0
# 2           house           Morelos  23.634501 -102.552788    360.0
# 3           house           Morelos        NaN         NaN     76.0
# 4           house            Puebla        NaN         NaN    200.0
# ..            ...               ...        ...         ...      ...
# 695         house           Morelos  18.917542  -98.963181    140.0
# 696         house  Distrito Federal  19.472128  -99.146697    190.0
# 697         house  Estado de México  19.234984  -99.558175    115.0
# 698         house            Puebla  18.918714  -98.426639     90.0
# 699         house           Yucatán  21.075163  -89.516731    185.0
#
#      price_mxn  price_usd
# 0    1300000.0    72800.0
# 1    2500000.0   140000.0
# 2    5300000.0   296800.0
# 3     820000.0    45920.0
# ...

# %%
# dict
df_2 = df_2.drop('price_mxn', axis=1)

# %%
df_2
# Out:
#     property_type             state        lat         lon  area_m2  price_usd
# 0       apartment        Nuevo León  25.721081 -100.345581     72.0    72800.0
# 1       apartment            Puebla        NaN         NaN    190.0   140000.0
# 2           house           Morelos  23.634501 -102.552788    360.0   296800.0
# 3           house           Morelos        NaN         NaN     76.0    45920.0
# 4           house            Puebla        NaN         NaN    200.0    61600.0
# ..            ...               ...        ...         ...      ...        ...
# 695         house           Morelos  18.917542  -98.963181    140.0    81200.0
# 696         house  Distrito Federal  19.472128  -99.146697    190.0   108808.0
# 697         house  Estado de México  19.234984  -99.558175    115.0   117600.0
# 698         house            Puebla  18.918714  -98.426639     90.0    49840.0
# 699         house           Yucatán  21.075163  -89.516731    185.0    94920.0
#
# [700 rows x 6 columns]

# %% [markdown]
# ##Table 3

# %%
df_3
# Out:
#     property_type                            place_with_parent_names  \
# 0       apartment  |México|Distrito Federal|Gustavo A. Madero|Acu...
# 1           house           |México|Estado de México|Toluca|Metepec|
# 2           house  |México|Estado de México|Toluca|Toluca de Lerd...
# 3           house        |México|Morelos|Temixco|Burgos Bugambilias|
# 4       apartment  |México|Veracruz de Ignacio de la Llave|Veracruz|
# ..            ...                                                ...
# 695         house  |México|Jalisco|Tlajomulco de Zúñiga|Tlajomulc...
# 696         house                          |México|Morelos|Jiutepec|
# 697         house                            |México|Yucatán|Mérida|
# 698         house           |México|San Luis Potosí|San Luis Potosí|
# 699         house           |México|Estado de México|Toluca|Metepec|
#
#                           lat-lon  area_m2  price_usd
# 0             19.52589,-99.151703     71.0   48550.59
# ...

# %%
df_3.dtypes
# Out:
# property_type               object
# place_with_parent_names     object
# lat-lon                     object
# area_m2                    float64
# price_usd                  float64
# dtype: object

# %%
# Split lat-lon column
df_3[['lat', 'lon']] = df_3['lat-lon'].str.split(',', 1, expand=True)
# Out:
# <ipython-input-39-bac9f546bb7b>:2: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df_3[['lat', 'lon']] = df_3['lat-lon'].str.split(',', 1, expand=True)

# %%
df_3 = df_3.drop('lat-lon', axis=1)

# %%
df_3

# %%
df_3.dtypes
# Out:
# property_type               object
# place_with_parent_names     object
# area_m2                    float64
# price_usd                  float64
# lat                        float64
# lon                        float64
# dtype: object

# %%
df_3['lat'] = df_3['lat'].astype(float)

# %%
df_3['lon'] = df_3['lon'].astype(float)

# %% [markdown]
# ##Union all

# %%
df = pd.concat([df_1, df_2, df_3])

# %%
df
# Out:
#     property_type                            state        lat         lon  \
# 0           house                 Estado de México  19.560181  -99.233528
# 1           house                       Nuevo León  25.688436 -100.198807
# 2       apartment                         Guerrero  16.767704  -99.764383
# 3       apartment                         Guerrero  16.829782  -99.911012
# 4           house  Veracruz de Ignacio de la Llave        NaN         NaN
# ..            ...                              ...        ...         ...
# 695         house                              NaN  20.532264 -103.484418
# 696         house                              NaN  18.928986  -99.180215
# 697         house                              NaN  21.028404  -89.653006
# 698         house                              NaN  22.118304 -101.032194
# 699         house                              NaN  19.233201  -99.558519
#
#      area_m2  price_usd                            place_with_parent_names
# ...

# %%
df.to_csv('/content/drive/MyDrive/MindX/MindX 18+ | D4E50/Day 12: Preprocessing và EDA dữ liệu/Data Practices/mexico-real-estate-cleaned.csv')

# %% [markdown]
# #EDA

# %%
df.shape
# Out:
# (2100, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2100 entries, 0 to 699
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   property_type            2100 non-null   object
#  1   state                    1400 non-null   object
#  2   lat                      1736 non-null   float64
#  3   lon                      1736 non-null   float64
#  4   area_m2                  2100 non-null   float64
#  5   price_usd                2100 non-null   float64
#  6   place_with_parent_names  700 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 131.2+ KB

# %%
df.describe()
# Out:
#                lat          lon      area_m2      price_usd
# count  1736.000000  1736.000000  2100.000000    2100.000000
# mean     20.765410   -98.798575   173.022857  119651.645206
# std       2.743425     4.882553    79.736156   67964.240972
# min      15.752900  -117.054763    60.000000   33192.480000
# 25%      19.275200  -100.392553   105.000000   67412.347500
# 50%      19.620518   -99.204001   160.000000  102763.000000
# 75%      21.073428   -98.245911   223.000000  156800.000000
# max      32.665619   -86.767539   385.000000  341600.000000

# %%
# correlation
df.corr()
# Out:
# <ipython-input-53-c1f0a49b9c47>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                 lat       lon   area_m2  price_usd
# lat        1.000000 -0.480231  0.082314  -0.083371
# lon       -0.480231  1.000000  0.095522   0.031713
# area_m2    0.082314  0.095522  1.000000   0.592644
# price_usd -0.083371  0.031713  0.592644   1.000000

# %%
df["property_type"].value_counts()
# Out:
# house        1634
# apartment     466
# Name: property_type, dtype: int64
